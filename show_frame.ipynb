# %%
import cv2
import matplotlib.pyplot as plt

# %%
video_path = '2024Nov28_resized/DJI_0057.MP4'
cap = cv2.VideoCapture(video_path)

# %%
ret, frame = cap.read()

# %%
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
plt.scatter(700,300,color='red')
